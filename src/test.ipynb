# %% [markdown]
# Class:
# 1 - Personality
# 2 - News and Media
# 3 - Company

# %%
from dataAquisition.scraping import scraping, init_driver

# %%
scrape_accounts = [
    # Personality
    {
        "user": "elonmusk",
        "dates": [
            # ["2010-01-01", "2011-01-01"],
            # ["2011-01-01", "2012-01-01"],
            # ["2012-01-01", "2013-01-01"],
            # ["2013-01-01", "2014-01-01"],
                # ["2014-01-01", "2015-01-01"],
            # ["2015-01-01", "2016-01-01"],
            # ["2016-01-01", "2017-01-01"],
            # ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '1'
    },
    {
        "user": "billgates",
        "dates": [
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '1'
    },
    {
        "user": "barackobama",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '1'
    },
    {
        "user": "emmanuelmacron",
        "dates": [
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '1'
    },
    {
        "user": "sanchezcastejon",
        "dates": [
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '1'
    },
    # Press EN
    {
        "user": "BBCNews",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '2'
    },
    {
        "user": "CNN",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '2'
    },
    {
        "user": "nytimes",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '2'
    },
    {
        "user": "guardian",
        "dates": [
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '2'
    },
    {
        "user": "Reuters",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ],
        "class": '2'
    },
    # Press FR


]

# %%
for scrape in scrape_accounts:
    for date in scrape["dates"]:
        print(f'Scraping from {date[0]} to {date[1]} for {scrape["user"]}')
        driver = init_driver(headless=True, show_images=False, env=".env")
        data = scraping(date[0], until=date[1], interval=2, from_account=scrape["user"], save_dir=f"../data/raw/{scrape['user']}", driver=driver, env=".env", headless=True, only_id=False, Class=scrape["class"])
# Out:
# Scraping from 2018-01-01 to 2019-01-01 for elonmusk
# Scraping on headless mode.
# looking for tweets between 2018-01-01 and 2018-01-03 ...
# Nb of Tweets : 0
# looking for tweets between 2018-01-03 and 2018-01-05 ...
# Nb of Tweets : 2
# looking for tweets between 2018-01-05 and 2018-01-07 ...
# Nb of Tweets : 2
# looking for tweets between 2018-01-07 and 2018-01-09 ...
# Nb of Tweets : 4
# looking for tweets between 2018-01-09 and 2018-01-11 ...
# Nb of Tweets : 2
# looking for tweets between 2018-01-11 and 2018-01-13 ...
# Nb of Tweets : 1
# looking for tweets between 2018-01-13 and 2018-01-15 ...
# Nb of Tweets : 0
# looking for tweets between 2018-01-15 and 2018-01-17 ...
# Nb of Tweets : 2
# looking for tweets between 2018-01-17 and 2018-01-19 ...
# Nb of Tweets : 1
# looking for tweets between 2018-01-19 and 2018-01-21 ...
# Nb of Tweets : 0
# looking for tweets between 2018-01-21 and 2018-01-23 ...
# Nb of Tweets : 0
# looking for tweets between 2018-01-23 and 2018-01-25 ...
# Nb of Tweets : 1
# looking for tweets between 2018-01-25 and 2018-01-27 ...
# Nb of Tweets : 0
# looking for tweets between 2018-01-27 and 2018-01-29 ...
# Nb of Tweets : 16
# looking for tweets between 2018-01-29 and 2018-01-31 ...
# Nb of Tweets : 9
# looking for tweets between 2018-01-31 and 2018-02-02 ...
# Nb of Tweets : 12
# looking for tweets between 2018-02-02 and 2018-02-04 ...
# Nb of Tweets : 8
# looking for tweets between 2018-02-04 and 2018-02-06 ...
# Nb of Tweets : 9
# looking for tweets between 2018-02-06 and 2018-02-08 ...
# Nb of Tweets : 17
# looking for tweets between 2018-02-08 and 2018-02-10 ...
# Nb of Tweets : 0
# looking for tweets between 2018-02-10 and 2018-02-12 ...
# Nb of Tweets : 3
# looking for tweets between 2018-02-12 and 2018-02-14 ...
# Nb of Tweets : 13
# looking for tweets between 2018-02-14 and 2018-02-16 ...
# Nb of Tweets : 0
# looking for tweets between 2018-02-16 and 2018-02-18 ...
# Nb of Tweets : 3
# looking for tweets between 2018-02-18 and 2018-02-20 ...
# Nb of Tweets : 1
# looking for tweets between 2018-02-20 and 2018-02-22 ...
# Nb of Tweets : 5
# looking for tweets between 2018-02-22 and 2018-02-24 ...
# Nb of Tweets : 11
# looking for tweets between 2018-02-24 and 2018-02-26 ...
# Nb of Tweets : 3
# looking for tweets between 2018-02-26 and 2018-02-28 ...
# Nb of Tweets : 6
# looking for tweets between 2018-02-28 and 2018-03-02 ...
# Nb of Tweets : 1
# looking for tweets between 2018-03-02 and 2018-03-04 ...
# Nb of Tweets : 1
# looking for tweets between 2018-03-04 and 2018-03-06 ...
# Nb of Tweets : 5
# looking for tweets between 2018-03-06 and 2018-03-08 ...
# Nb of Tweets : 7
# looking for tweets between 2018-03-08 and 2018-03-10 ...
# Nb of Tweets : 18
# looking for tweets between 2018-03-10 and 2018-03-12 ...
# Nb of Tweets : 7
# looking for tweets between 2018-03-12 and 2018-03-14 ...
# Nb of Tweets : 1
# looking for tweets between 2018-03-14 and 2018-03-16 ...
# Nb of Tweets : 8
# looking for tweets between 2018-03-16 and 2018-03-18 ...
# Nb of Tweets : 0
# looking for tweets between 2018-03-18 and 2018-03-20 ...
# Nb of Tweets : 2
# looking for tweets between 2018-03-20 and 2018-03-22 ...
# Nb of Tweets : 4
# looking for tweets between 2018-03-22 and 2018-03-24 ...
# Nb of Tweets : 29
# looking for tweets between 2018-03-24 and 2018-03-26 ...
# Nb of Tweets : 4
# looking for tweets between 2018-03-26 and 2018-03-28 ...
# Nb of Tweets : 11
# looking for tweets between 2018-03-28 and 2018-03-30 ...
# Nb of Tweets : 4
# looking for tweets between 2018-03-30 and 2018-04-01 ...
# Nb of Tweets : 8
# looking for tweets between 2018-04-01 and 2018-04-03 ...
# Nb of Tweets : 18
# looking for tweets between 2018-04-03 and 2018-04-05 ...
# Nb of Tweets : 3
# looking for tweets between 2018-04-05 and 2018-04-07 ...
# Nb of Tweets : 6
# looking for tweets between 2018-04-07 and 2018-04-09 ...
# Nb of Tweets : 10
# looking for tweets between 2018-04-09 and 2018-04-11 ...
# Nb of Tweets : 5
# looking for tweets between 2018-04-11 and 2018-04-13 ...
# Nb of Tweets : 3
# looking for tweets between 2018-04-13 and 2018-04-15 ...
# Nb of Tweets : 6
# looking for tweets between 2018-04-15 and 2018-04-17 ...
# Nb of Tweets : 9
# looking for tweets between 2018-04-17 and 2018-04-19 ...
# Nb of Tweets : 9
# looking for tweets between 2018-04-19 and 2018-04-21 ...
# Nb of Tweets : 0
# looking for tweets between 2018-04-21 and 2018-04-23 ...
# Nb of Tweets : 0
# looking for tweets between 2018-04-23 and 2018-04-25 ...
# Nb of Tweets : 1
# looking for tweets between 2018-04-25 and 2018-04-27 ...
# Nb of Tweets : 6
# looking for tweets between 2018-04-27 and 2018-04-29 ...
# Nb of Tweets : 3
# looking for tweets between 2018-04-29 and 2018-05-01 ...
# Nb of Tweets : 2
# looking for tweets between 2018-05-01 and 2018-05-03 ...
# Nb of Tweets : 7
# looking for tweets between 2018-05-03 and 2018-05-05 ...
# Nb of Tweets : 17
# looking for tweets between 2018-05-05 and 2018-05-07 ...
# Nb of Tweets : 18
# looking for tweets between 2018-05-07 and 2018-05-09 ...
# Nb of Tweets : 6
# looking for tweets between 2018-05-09 and 2018-05-11 ...
# Nb of Tweets : 19
# looking for tweets between 2018-05-11 and 2018-05-13 ...
# Nb of Tweets : 18
# looking for tweets between 2018-05-13 and 2018-05-15 ...
# Nb of Tweets : 13
# looking for tweets between 2018-05-15 and 2018-05-17 ...
# Nb of Tweets : 3
# looking for tweets between 2018-05-17 and 2018-05-19 ...
# Nb of Tweets : 10
# looking for tweets between 2018-05-19 and 2018-05-21 ...
# Nb of Tweets : 24
# looking for tweets between 2018-05-21 and 2018-05-23 ...
# Nb of Tweets : 44
# looking for tweets between 2018-05-23 and 2018-05-25 ...
# Nb of Tweets : 50
# looking for tweets between 2018-05-25 and 2018-05-27 ...
# Nb of Tweets : 50
# looking for tweets between 2018-05-27 and 2018-05-29 ...
# Nb of Tweets : 25
# looking for tweets between 2018-05-29 and 2018-05-31 ...
# Nb of Tweets : 35
# looking for tweets between 2018-05-31 and 2018-06-02 ...
# Nb of Tweets : 22
# looking for tweets between 2018-06-02 and 2018-06-04 ...
# Nb of Tweets : 20
# looking for tweets between 2018-06-04 and 2018-06-06 ...
# Nb of Tweets : 4
# looking for tweets between 2018-06-06 and 2018-06-08 ...
# Nb of Tweets : 7
# looking for tweets between 2018-06-08 and 2018-06-10 ...
# Nb of Tweets : 22
# looking for tweets between 2018-06-10 and 2018-06-12 ...
# Nb of Tweets : 26
# looking for tweets between 2018-06-12 and 2018-06-14 ...
# Nb of Tweets : 5
# looking for tweets between 2018-06-14 and 2018-06-16 ...
# Nb of Tweets : 19
# looking for tweets between 2018-06-16 and 2018-06-18 ...
# Nb of Tweets : 50
# looking for tweets between 2018-06-18 and 2018-06-20 ...
# Nb of Tweets : 35
# looking for tweets between 2018-06-20 and 2018-06-22 ...
# Nb of Tweets : 18
# looking for tweets between 2018-06-22 and 2018-06-24 ...
# Nb of Tweets : 34
# looking for tweets between 2018-06-24 and 2018-06-26 ...
# Nb of Tweets : 30
# looking for tweets between 2018-06-26 and 2018-06-28 ...
# Nb of Tweets : 23
# looking for tweets between 2018-06-28 and 2018-06-30 ...
# Nb of Tweets : 31
# looking for tweets between 2018-06-30 and 2018-07-02 ...
# Nb of Tweets : 2
# looking for tweets between 2018-07-02 and 2018-07-04 ...
# Nb of Tweets : 5
# looking for tweets between 2018-07-04 and 2018-07-06 ...
# Nb of Tweets : 38
# looking for tweets between 2018-07-06 and 2018-07-08 ...
# Nb of Tweets : 31
# looking for tweets between 2018-07-08 and 2018-07-10 ...
# Nb of Tweets : 31
# looking for tweets between 2018-07-10 and 2018-07-12 ...
# Nb of Tweets : 35
# looking for tweets between 2018-07-12 and 2018-07-14 ...
# Nb of Tweets : 24
# looking for tweets between 2018-07-14 and 2018-07-16 ...
# Nb of Tweets : 19
# looking for tweets between 2018-07-16 and 2018-07-18 ...
# Nb of Tweets : 1
# looking for tweets between 2018-07-18 and 2018-07-20 ...
# Nb of Tweets : 4
# looking for tweets between 2018-07-20 and 2018-07-22 ...
# Nb of Tweets : 23
# looking for tweets between 2018-07-22 and 2018-07-24 ...
# Nb of Tweets : 9
# Nb of Tweets : 17
# looking for tweets between 2018-08-03 and 2018-08-05 ...
# Nb of Tweets : 1
# looking for tweets between 2018-08-05 and 2018-08-07 ...
# Nb of Tweets : 20
# looking for tweets between 2018-08-07 and 2018-08-09 ...
# Nb of Tweets : 14
# looking for tweets between 2018-08-09 and 2018-08-11 ...
# Nb of Tweets : 2
# looking for tweets between 2018-08-11 and 2018-08-13 ...
# Nb of Tweets : 15
# looking for tweets between 2018-08-13 and 2018-08-15 ...
# Nb of Tweets : 8
# looking for tweets between 2018-08-15 and 2018-08-17 ...
# Nb of Tweets : 4
# looking for tweets between 2018-08-17 and 2018-08-19 ...
# Nb of Tweets : 2
# looking for tweets between 2018-08-19 and 2018-08-21 ...
# Nb of Tweets : 2
# looking for tweets between 2018-08-21 and 2018-08-23 ...
# Nb of Tweets : 9
# looking for tweets between 2018-08-23 and 2018-08-25 ...
# Nb of Tweets : 9
# looking for tweets between 2018-08-25 and 2018-08-27 ...
# Nb of Tweets : 14
# looking for tweets between 2018-08-27 and 2018-08-29 ...
# Nb of Tweets : 11
# looking for tweets between 2018-08-29 and 2018-08-31 ...
# Nb of Tweets : 2
# looking for tweets between 2018-08-31 and 2018-09-02 ...
# Nb of Tweets : 3
# looking for tweets between 2018-09-02 and 2018-09-04 ...
# Nb of Tweets : 1
# looking for tweets between 2018-09-04 and 2018-09-06 ...
# Nb of Tweets : 2
# looking for tweets between 2018-09-06 and 2018-09-08 ...
# Nb of Tweets : 7
# looking for tweets between 2018-09-08 and 2018-09-10 ...
# Nb of Tweets : 5
# looking for tweets between 2018-09-10 and 2018-09-12 ...
# Nb of Tweets : 4
# looking for tweets between 2018-09-12 and 2018-09-14 ...
# Nb of Tweets : 7
# looking for tweets between 2018-09-14 and 2018-09-16 ...
# Nb of Tweets : 11
# looking for tweets between 2018-09-16 and 2018-09-18 ...
# Nb of Tweets : 32
# looking for tweets between 2018-09-18 and 2018-09-20 ...
# Nb of Tweets : 24
# looking for tweets between 2018-09-20 and 2018-09-22 ...
# Nb of Tweets : 17
# looking for tweets between 2018-09-22 and 2018-09-24 ...
# Nb of Tweets : 1
# looking for tweets between 2018-09-24 and 2018-09-26 ...
# Nb of Tweets : 6
# looking for tweets between 2018-09-26 and 2018-09-28 ...
# Nb of Tweets : 3
# looking for tweets between 2018-09-28 and 2018-09-30 ...
# Nb of Tweets : 7
# looking for tweets between 2018-09-30 and 2018-10-02 ...
# Nb of Tweets : 1
# looking for tweets between 2018-10-02 and 2018-10-04 ...
# Nb of Tweets : 1
# looking for tweets between 2018-10-04 and 2018-10-06 ...
# Nb of Tweets : 27
# looking for tweets between 2018-10-06 and 2018-10-08 ...
# Nb of Tweets : 7
# looking for tweets between 2018-10-08 and 2018-10-10 ...
# Nb of Tweets : 13
# looking for tweets between 2018-10-10 and 2018-10-12 ...
# Nb of Tweets : 5
# looking for tweets between 2018-10-12 and 2018-10-14 ...
# Nb of Tweets : 11
# looking for tweets between 2018-10-14 and 2018-10-16 ...
# Nb of Tweets : 16
# looking for tweets between 2018-10-16 and 2018-10-18 ...
# Nb of Tweets : 14
# looking for tweets between 2018-10-18 and 2018-10-20 ...
# Nb of Tweets : 18
# looking for tweets between 2018-10-20 and 2018-10-22 ...
# Nb of Tweets : 16
# looking for tweets between 2018-10-22 and 2018-10-24 ...
# Nb of Tweets : 25
# looking for tweets between 2018-10-24 and 2018-10-26 ...
# Nb of Tweets : 19
# looking for tweets between 2018-10-26 and 2018-10-28 ...
# Nb of Tweets : 42
# looking for tweets between 2018-10-28 and 2018-10-30 ...
# Nb of Tweets : 3
# looking for tweets between 2018-10-30 and 2018-11-01 ...
# Nb of Tweets : 3
# looking for tweets between 2018-11-01 and 2018-11-03 ...
# Nb of Tweets : 23
# looking for tweets between 2018-11-03 and 2018-11-05 ...
# Nb of Tweets : 22
# looking for tweets between 2018-11-05 and 2018-11-07 ...
# Nb of Tweets : 10
# looking for tweets between 2018-11-07 and 2018-11-09 ...
# Nb of Tweets : 8
# looking for tweets between 2018-11-09 and 2018-11-11 ...
# Nb of Tweets : 13
# looking for tweets between 2018-11-11 and 2018-11-13 ...
# Nb of Tweets : 3
# looking for tweets between 2018-11-13 and 2018-11-15 ...
# Nb of Tweets : 8
# looking for tweets between 2018-11-15 and 2018-11-17 ...
# Nb of Tweets : 20
# looking for tweets between 2018-11-17 and 2018-11-19 ...
# Nb of Tweets : 10
# looking for tweets between 2018-11-19 and 2018-11-21 ...
# Nb of Tweets : 25
# looking for tweets between 2018-11-21 and 2018-11-23 ...
# Nb of Tweets : 9
# looking for tweets between 2018-11-23 and 2018-11-25 ...
# Nb of Tweets : 1
# looking for tweets between 2018-11-25 and 2018-11-27 ...
# Nb of Tweets : 16
# looking for tweets between 2018-11-27 and 2018-11-29 ...
# Nb of Tweets : 6
# looking for tweets between 2018-11-29 and 2018-12-01 ...
# Nb of Tweets : 18
# looking for tweets between 2018-12-01 and 2018-12-03 ...
# Nb of Tweets : 20
# looking for tweets between 2018-12-03 and 2018-12-05 ...
# Nb of Tweets : 5
# looking for tweets between 2018-12-05 and 2018-12-07 ...
# Nb of Tweets : 7
# looking for tweets between 2018-12-07 and 2018-12-09 ...
# Nb of Tweets : 2
# looking for tweets between 2018-12-09 and 2018-12-11 ...
# Nb of Tweets : 15
# looking for tweets between 2018-12-11 and 2018-12-13 ...
# Nb of Tweets : 15
# looking for tweets between 2018-12-13 and 2018-12-15 ...
# Nb of Tweets : 6
# looking for tweets between 2018-12-15 and 2018-12-17 ...
# Nb of Tweets : 8
# looking for tweets between 2018-12-17 and 2018-12-19 ...
# Nb of Tweets : 8
# looking for tweets between 2018-12-19 and 2018-12-21 ...
# Nb of Tweets : 36
# looking for tweets between 2018-12-21 and 2018-12-23 ...
# Nb of Tweets : 27
# looking for tweets between 2018-12-23 and 2018-12-25 ...
# Nb of Tweets : 20
# looking for tweets between 2018-12-25 and 2018-12-27 ...
# Nb of Tweets : 18
# looking for tweets between 2018-12-27 and 2018-12-29 ...
# Nb of Tweets : 11
# looking for tweets between 2018-12-29 and 2018-12-31 ...
# Nb of Tweets : 3
# Scraping from 2019-01-01 to 2020-01-01 for elonmusk
# Scraping on headless mode.
# Error while logging in. Retrying... (1/5)
# Error while logging in. Retrying... (2/5)
# Error while logging in. Retrying... (3/5)
# Error while logging in. Retrying... (4/5)
# Error while logging in. Retrying... (5/5)
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connectionpool.py:415, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414     else:
# --> 415         conn.request(method, url, **httplib_request_kw)
#     417 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     418 # legitimately able to close the connection after sending a valid response.
#     419 # With this behaviour, the received response is still readable.
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x128aa2810>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[5], line 5
#       3 print(f'Scraping from {date[0]} to {date[1]} for {scrape["user"]}')
#       4 driver = init_driver(headless=True, show_images=False, env=".env")
# ----> 5 data = scraping(date[0], until=date[1], interval=2, from_account=scrape["user"], save_dir=f"../data/raw/{scrape['user']}", driver=driver, env=".env", headless=True, only_id=False, Class=scrape["class"])
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/src/dataAquisition/scraping.py:109, in scraping(since, until, words, to_account, from_account, mention_account, interval, lang, headless, limit, display_type, resume, proxy, hashtag, save_dir, filter_replies, proximity, geocode, minreplies, minlikes, minretweets, driver, env, only_id, Class)
#     107     until_local = datetime.datetime.strftime(until_local, '%Y-%m-%d')
#     108 # log search page between <since> and <until_local>
# --> 109 path = log_search_page(driver=driver, words=words, since=since,
#     110                        until_local=until_local, to_account=to_account,
#     111                        from_account=from_account, mention_account=mention_account, hashtag=hashtag,
#     112                        lang=lang,
#     113                        display_type=display_type, filter_replies=filter_replies, proximity=proximity,
#     114                        geocode=geocode, minreplies=minreplies, minlikes=minlikes, minretweets=minretweets)
#     115 # number of logged pages (refresh each <interval>)
#     116 refresh += 1
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/src/dataAquisition/utils.py:217, in log_search_page(driver, since, until_local, lang, display_type, words, to_account, from_account, mention_account, hashtag, filter_replies, proximity, geocode, minreplies, minlikes, minretweets)
#     214     proximity = ""
#     216 path = 'https://twitter.com/search?q=' + words + from_account + to_account + mention_account + hash_tags + until_local + since + lang + filter_replies + geocode + minreplies + minlikes + minretweets + '&src=typed_query' + display_type + proximity
# --> 217 driver.get(path)
#     218 return path
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.get(self, url)
#     438 def get(self, url: str) -> None:
#     439     """
#     440     Loads a web page in the current browser session.
#     441     """
# --> 442     self.execute(Command.GET, {'url': url})
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     425         params['sessionId'] = self.session_id
#     427 params = self._wrap_value(params)
# --> 428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
#     430     self.error_handler.check_response(response)
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:347, in RemoteConnection.execute(self, command, params)
#     345 data = utils.dump_json(params)
#     346 url = f"{self._url}{path}"
# --> 347 return self._request(command_info[0], url, body=data)
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:369, in RemoteConnection._request(self, method, url, body)
#     366     body = None
#     368 if self.keep_alive:
# --> 369     response = self._conn.request(method, url, body=body, headers=headers)
#     370     statuscode = response.status
#     371 else:
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connectionpool.py:826, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     821 if not conn:
#     822     # Try again
#     823     log.warning(
#     824         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     825     )
# --> 826     return self.urlopen(
#     827         method,
#     828         url,
#     829         body,
#     830         headers,
#     831         retries,
#     832         redirect,
#     833         assert_same_host,
#     834         timeout=timeout,
#     835         pool_timeout=pool_timeout,
#     836         release_conn=release_conn,
#     837         chunked=chunked,
#     838         body_pos=body_pos,
#     839         **response_kw
#     840     )
#     842 # Handle redirect?
#     843 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connectionpool.py:826, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     821 if not conn:
#     822     # Try again
#     823     log.warning(
#     824         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     825     )
# --> 826     return self.urlopen(
#     827         method,
#     828         url,
#     829         body,
#     830         headers,
#     831         retries,
#     832         redirect,
#     833         assert_same_host,
#     834         timeout=timeout,
#     835         pool_timeout=pool_timeout,
#     836         release_conn=release_conn,
#     837         chunked=chunked,
#     838         body_pos=body_pos,
#     839         **response_kw
#     840     )
#     842 # Handle redirect?
#     843 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connectionpool.py:826, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     821 if not conn:
#     822     # Try again
#     823     log.warning(
#     824         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     825     )
# --> 826     return self.urlopen(
#     827         method,
#     828         url,
#     829         body,
#     830         headers,
#     831         retries,
#     832         redirect,
#     833         assert_same_host,
#     834         timeout=timeout,
#     835         pool_timeout=pool_timeout,
#     836         release_conn=release_conn,
#     837         chunked=chunked,
#     838         body_pos=body_pos,
#     839         **response_kw
#     840     )
#     842 # Handle redirect?
#     843 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     795 elif isinstance(e, (SocketError, HTTPException)):
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#     803 # Keep track of the error for the retry warning.
#
# File ~/Jupyter_notebooks/Noisy_Entropy_Estimation/Try/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     581 new_retry = self.new(
#     582     total=total,
#     583     connect=connect,
#    (...)
#     588     history=history,
#     589 )
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     596 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=58407): Max retries exceeded with url: /session/49a140e725ba235e9c271e4c993555a3/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x128aa2810>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
data
# Out:
#                Tweet_ID   User_ID                 Timestamp
# 0    153574532031070208  44196397  2012-01-01T20:33:16.000Z  \
# 1    153578511687368704  44196397  2012-01-01T20:49:05.000Z
# 2    153515940707975169  44196397  2012-01-01T16:40:27.000Z
# 3    153594528908058624  44196397  2012-01-01T21:52:44.000Z
# 4    153576623101313025  44196397  2012-01-01T20:41:34.000Z
# ..                  ...       ...                       ...
# 253  283037363763032066  44196397  2012-12-24T02:32:20.000Z
# 254  283034463372464129  44196397  2012-12-24T02:20:49.000Z
# 255  283694250980429824  44196397  2012-12-25T22:02:34.000Z
# 256  285026400078016512  44196397  2012-12-29T14:16:03.000Z
# 257  285026647151894528  44196397  2012-12-29T14:17:02.000Z
#
#                                                   Text Emojis Class
# 0    We built powerful information weapons to fight...            1
# 1    I said *information* weapons for a reason. The...            1
# 2    My first prediction of 2012 has come true: ouc...            1
# 3    On a lighter note, the RHCP are f* awesome. No...            1
# 4    If we are not careful, we will find that knife...            1
# ..                                                 ...    ...   ...
# 253    Single camera view of the 40 meter rocket hover            1
# 254  Then we took him for a ride: 40 meter hover fl...            1
# 255               @TristanLaurent  V cute! Merry Xmas.            1
# 256  CA's Death Valley is #1 again! Tesla hot weath...            1
# 257  Death Valley restored to position of world's h...            1
#
# [258 rows x 6 columns]

# %% [markdown]
# # COMBINE DATA

# %%
import os
import pandas as pd

# Define your directory
directory = '../data/raw/bbcnews'
final = 'bbcnews_all.csv'
# Get a list of all csv files
files = [f for f in os.listdir(directory) if f.endswith('.csv')]

for f in files:
    print(f)

# Create full file paths
full_paths = [os.path.join(directory, f) for f in files]

# Read the files into dataframes and store in a list
dfs = [pd.read_csv(fp) for fp in full_paths]

# Concatenate all dataframes
df = pd.concat(dfs, ignore_index=True)

# Save the result to a new CSV file
df.to_csv(os.path.join(directory, final), index=False)
# Out:
# BBCNews_2011-01-01_2012-01-01.csv
# BBCNews_2012-01-01_2013-01-01.csv
# BBCNews_2007-01-01_2008-01-01.csv
# BBCNews_2009-01-01_2010-01-01.csv
# BBCNews_2010-01-01_2011-01-01.csv
# BBCNews_2008-01-01_2009-01-01.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data
df = pd.read_csv('../data/raw/bbcnews/bbcnews_all.csv')

# Convert Timestamp to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Set Timestamp as index (this is required for resampling)
df.set_index('Timestamp', inplace=True)

# Resample the data to daily frequency, count the number of tweets per day
df_daily = df.resample('D').count()

# Reset index so that 'Timestamp' becomes a column again
df_daily.reset_index(inplace=True)

# Plot the data
plt.figure(figsize=(10, 6))
sns.barplot(x='Timestamp', y='Tweet_ID', data=df_daily)
plt.title('Number of tweets over time')
plt.xlabel('Date')
plt.xticks([])
plt.ylabel('Number of tweets')
plt.show()

# %%
len(df)
# Out:
# 84197

# %%
import json
import pandas as pd

data = json.loads(s=open("/Users/admin/sample.json").read())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 import json
#       2 import pandas as pd
# ----> 4 data = json.loads(s=open("/Users/admin/sample.json").read())
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 2 column 1 (char 4688)

# %%
with open("/Users/admin/sample.json") as f:
    data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 2
#       1 with open("/Users/admin/sample.json") as f:
# ----> 2     data = json.load(f)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 2 column 1 (char 4688)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import twarc

# %%
import pandas as pd
df = pd.read_csv("../data/sample-stream/2023-05-29.csv")

# %%
len(df)
# Out:
# 100103

# %%
print(df["lang"].unique())
# Out:
# ['qme' 'ar' 'en' 'th' 'fa' 'ja' 'es' 'zh' 'pl' 'qht' 'bn' 'ko' 'tr' 'ur'
#  'hi' 'und' 'zxx' 'pt' 'nl' 'tl' 'no' 'fr' 'fi' 'it' 'in' 'ru' 'ta' 'lv'
#  'el' 'te' 'de' 'et' 'qam' 'cy' 'sr' 'ca' 'ht' 'qst' 'ro' 'da' 'mr' 'gu'
#  'iw' 'sv' 'uk' 'lt' 'eu' 'hu' 'cs' 'my' 'ml' 'kn' 'dv' 'bg' 'vi' 'art'
#  'ne' 'pa' 'is' 'sl' 'km' 'ckb' 'am' 'ps' 'ka' 'or' 'si' 'hy' 'qct' 'lo']

# %%
len(df[df["lang"] == "it"])
# Out:
# 570
