# %% [markdown]
# Class:
# 1 - Personality
# 2 - News and Media
# 3 - Company

# %%
from dataAquisition.scrape import scrape, init_driver

# %%
scrape_accounts = [
    # Personality
    {
        "user": "elonmusk",
        "dates": [
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    {
        "user": "billgates",
        "dates": [
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    {
        "user": "barackobama",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    {
        "user": "emmanuelmacron",
        "dates": [
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    {
        # Spanish
        "user": "sanchezcastejon",
        "dates": [
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    # Press EN
    {
        "user": "BBCNews",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    {
        "user": "CNN",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    {
        "user": "nytimes",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    {
        "user": "guardian",
        "dates": [
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    {
        "user": "Reuters",
        "dates": [
            ["2007-01-01", "2008-01-01"],
            ["2008-01-01", "2009-01-01"],
            ["2009-01-01", "2010-01-01"],
            ["2010-01-01", "2011-01-01"],
            ["2011-01-01", "2012-01-01"],
            ["2012-01-01", "2013-01-01"],
            ["2013-01-01", "2014-01-01"],
            ["2014-01-01", "2015-01-01"],
            ["2015-01-01", "2016-01-01"],
            ["2016-01-01", "2017-01-01"],
            ["2017-01-01", "2018-01-01"],
            ["2018-01-01", "2019-01-01"],
            ["2019-01-01", "2020-01-01"],
            ["2020-01-01", "2021-01-01"],
            ["2021-01-01", "2022-01-01"]
        ]
    },
    # Press FR


]

# %%
for scrape in scrape_accounts:
    for date in scrape["dates"]:
        print(f'Scraping from {date[0]} to {date[1]} for {scrape["user"]}')
        driver = init_driver(headless=True, show_images=False, env=".env")
        data = scrape(date[0], until=date[1], interval=2, from_account=scrape["user"], save_dir=f"../data/raw/{scrape['user']}", driver=driver, env=".env", headless=True, only_id=False, Class='1')

# %%
for date in dates:
    print(f'Scraping from {date[0]} to {date[1]}')
    driver = init_driver(headless=True, show_images=False, env=".env")
    data = scrape(date[0], until=date[1], interval=2, from_account="elonmusk", save_dir="../data/raw/ElonMusk", driver=driver, env=".env", headless=True, only_id=False, Class='1')
# Out:
# Scraping from 2013-01-01 to 2013-12-31
# Scraping on headless mode.
# looking for tweets between 2013-01-01 and 2013-01-03 ...
# Nb of Tweets : 0
# looking for tweets between 2013-01-03 and 2013-01-05 ...
# Nb of Tweets : 2
# looking for tweets between 2013-01-05 and 2013-01-07 ...
# Nb of Tweets : 0
# looking for tweets between 2013-01-07 and 2013-01-09 ...
# Nb of Tweets : 0
# looking for tweets between 2013-01-09 and 2013-01-11 ...
# Nb of Tweets : 2
# looking for tweets between 2013-01-11 and 2013-01-13 ...
# Nb of Tweets : 0
# looking for tweets between 2013-01-13 and 2013-01-15 ...
# Nb of Tweets : 0
# looking for tweets between 2013-01-15 and 2013-01-17 ...
# Nb of Tweets : 1
# looking for tweets between 2013-01-17 and 2013-01-19 ...
# Nb of Tweets : 0
# looking for tweets between 2013-01-19 and 2013-01-21 ...
# Nb of Tweets : 0
# looking for tweets between 2013-01-21 and 2013-01-23 ...
# Nb of Tweets : 0
# looking for tweets between 2013-01-23 and 2013-01-25 ...
# ...

# %%
driver = init_driver(headless=True, show_images=False, env=".env")
data = scrape("2012-01-01", until="2012-12-31", interval=2, from_account="elonmusk", save_dir="../data/raw/ElonMusk", driver=driver, env=".env", headless=True, only_id=False, Class='1')
# Out:
# Scraping on headless mode.
# Error while logging in. Retrying... (1/5)
# looking for tweets between 2012-01-01 and 2012-01-03 ...
# Nb of Tweets : 7
# looking for tweets between 2012-01-03 and 2012-01-05 ...
# Nb of Tweets : 3
# looking for tweets between 2012-01-05 and 2012-01-07 ...
# Nb of Tweets : 3
# looking for tweets between 2012-01-07 and 2012-01-09 ...
# Nb of Tweets : 0
# looking for tweets between 2012-01-09 and 2012-01-11 ...
# Nb of Tweets : 0
# looking for tweets between 2012-01-11 and 2012-01-13 ...
# Nb of Tweets : 4
# looking for tweets between 2012-01-13 and 2012-01-15 ...
# Nb of Tweets : 3
# looking for tweets between 2012-01-15 and 2012-01-17 ...
# Nb of Tweets : 0
# looking for tweets between 2012-01-17 and 2012-01-19 ...
# Nb of Tweets : 4
# looking for tweets between 2012-01-19 and 2012-01-21 ...
# Nb of Tweets : 0
# looking for tweets between 2012-01-21 and 2012-01-23 ...
# Nb of Tweets : 1
# looking for tweets between 2012-01-23 and 2012-01-25 ...
# ...

# %%
data
# Out:
#                Tweet_ID   User_ID                 Timestamp
# 0    153574532031070208  44196397  2012-01-01T20:33:16.000Z  \
# 1    153578511687368704  44196397  2012-01-01T20:49:05.000Z
# 2    153515940707975169  44196397  2012-01-01T16:40:27.000Z
# 3    153594528908058624  44196397  2012-01-01T21:52:44.000Z
# 4    153576623101313025  44196397  2012-01-01T20:41:34.000Z
# ..                  ...       ...                       ...
# 253  283037363763032066  44196397  2012-12-24T02:32:20.000Z
# 254  283034463372464129  44196397  2012-12-24T02:20:49.000Z
# 255  283694250980429824  44196397  2012-12-25T22:02:34.000Z
# 256  285026400078016512  44196397  2012-12-29T14:16:03.000Z
# 257  285026647151894528  44196397  2012-12-29T14:17:02.000Z
#
#                                                   Text Emojis Class
# 0    We built powerful information weapons to fight...            1
# 1    I said *information* weapons for a reason. The...            1
# ...
